# %% [markdown]
# # Geocode
#
# Mapping the H2A visa work sites

# %% [markdown]
# *Added by Steve*
#
# Essentially this notebook takes the various, often dirty, geolocation data from the transformed data and resolves these geolocation entitites by city and state. When the city column contains dirty data, it has the added benefit of "cleaning" that column.

# %%
import os
import csv
import time
import random
import calculate
import numpy as np
import pandas as pd
import timeout_decorator
from geopy import Location
from geopy.geocoders import Bing

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Read in all the visas

# %%
df = pd.concat([
    pd.read_csv("./output/transformed_master_cases.csv"),
    pd.read_csv("./output/transformed_sub_cases.csv"),
])

# %%
# Added by Steve, peek at df
df.head()
# Out:
#      case_number       case_status certification_start_date  \
# 0  C-07318-06766  Certified - Full               2008-01-01
# 1  C-07271-06353  Certified - Full               2008-01-02
# 2  C-07261-06276  Certified - Full               2008-01-01
# 3  C-07310-06649  Certified - Full               2008-01-01
# 4  C-07317-06700  Certified - Full               2008-01-01
#
#    certification_start_year          city crop             employer  \
# 0                    2008.0        BASILE  NaN  TEPETATE GATOR CORP
# 1                    2008.0      CENTURIA  NaN          HANJO FARMS
# 2                    2008.0  SPANISH FARK  NaN    SOUTH SHORE FARMS
# 3                    2008.0          ENID  NaN        BRYAN KROEKER
# 4                    2008.0  LAKE CHARLES  NaN    PAUL HEINEN FARMS
#
#    fiscal_year                        job_title latimes_crop latimes_id  \
# 0         2008            LABORER, AQUATIC LIFE          NaN     2008-3
# 1         2008  FARMWORKER, DIVERSIFIED CROPS I          NaN     2008-4
# 2         2008             FARMWORKER, FRUIT II          NaN     2008-5
# 3         2008            FARMWORKER, GENERAL I          NaN     2008-6
# 4         2008                 FARMWORKER, RICE          NaN     2008-7
#
#   master_case  row_number state  workers_certified
# 0       False           3    LA                  5
# 1       False           4    WI                  1
# 2       False           5    UT                 20
# 3       False           6    OK                  8
# 4       False           7    LA                  5

# %% [markdown]
# Extract the distinct locations

# %%
# Added by Steve, city column still requires cleaning
df.groupby(['city', 'state']).size()
# Out:
# city                                                state
# 1) WENDEN 2)TONOPAH  3) DATELAND                    AZ         1
# 1.- TONOPAH                           2.- DATELAND  AR         1
# 1090 STEVENS RANCH ROAD                             TX         1
# 1561 RAYBURN RD                                     KY         1
# 16001 311TH AVE                                     SD         1
# 18 MILES NORTH OF CAREY                             ID         2
# 208 Hesperian Way                                   WA         2
# 2279 S.E. REYNOLDS STREET                           FL         1
# 230 CAMERON AVENUE                                  NC         5
# 28525                                               NC         1
# 33 CADDO                                            TX         1
# 7317 N. Andre Rd.                                   KS         1
# 93219                                               CA         2
# ABBEVILLE                                           AL         7
#                                                     LA        41
# ABERDEEN                                            ID        13
#                                                     SD         7
# ABILENE                                             TX         2
# ABINGDON                                            MD         3
# ABSAROKEE                                           MT        13
# ABSORAKEE                                           MT         5
# ACCORD                                              NY         6
# ACKERLY                                             TX         8
# ACKLEY                                              IA         3
# ACTON                                               MA        30
#                                                     ME         5
# ADA                                                 MI         1
#                                                     MN         2
#                                                     OK         1
# ADAIRVILLE                                          KY       141
#                                                             ...
# medina                                              NY         1
# montrose                                            CO         2
# north brookfield                                    MA         3
# north scituate                                      RI         5
# oZONA                                               TX         2
# pembroke                                            KY         1
# pioneer                                             LA         1
# santa maria                                         CA         4
# seminole                                            TX         2
# sonoma                                              CA         2
# souris                                              ND         2
# southwick                                           MA         3
# sterling                                            MA         4
# stow                                                MA        13
# suffield                                            CT        10
# sunderland                                          MA         6
# various range locations                             UT         1
# vass                                                NC        43
# w paris                                             ME         1
# wasco                                               CA         2
# waterport                                           NY         2
# west paris                                          ME         4
# westfall                                            OR         2
# westford                                            MA         1
# westport                                            NY         1
# whately                                             MA         6
# whitney                                             NE         1
# whittemore                                          IA         1
# winchester                                          VA         2
# wolcott                                             NY         2
# Length: 9253, dtype: int64

# %%
locations = df.groupby(['city', 'state']).size().reset_index().rename(columns={0: "count"})

# %%
# Added by Steve, what do we have?
locations.head()
# Out:
#                                                 city state  count
# 0                   1) WENDEN 2)TONOPAH  3) DATELAND    AZ      1
# 1  1.- TONOPAH                           2.- DATE...    AR      1
# 2                            1090 STEVENS RANCH ROAD    TX      1
# 3                                    1561 RAYBURN RD    KY      1
# 4                                    16001 311TH AVE    SD      1

# %% [markdown]
# Read in previously geocoded locations

# %%
geocoded = pd.read_csv("./output/geocoded.csv")

# %%
# Added by Steve
geocoded.head()
# Out:
#                                                  key  \
# 0               1) WENDEN 2)TONOPAH  3) DATELAND, AZ
# 1  1.- TONOPAH                           2.- DATE...
# 2                        1090 STEVENS RANCH ROAD, TX
# 3                                1561 RAYBURN RD, KY
# 4                                16001 311TH AVE, SD
#
#                                    geocoder_address        lat         lng  \
# 0                       Dateland, AZ, United States  32.799599 -113.540932
# 1                                 AR, United States  34.899921  -92.438873
# 2  1090 Stevens Ranch Rd, Pipe Creek, TX 78063, USA  29.774711  -99.078929
# 3            1561 Rayburn Rd, Murray, KY 42071, USA  36.569439  -88.441078
# 4              16001 311th Ave, Agar, SD 57520, USA  44.896279  -99.939442
#
#         geocoder_type
# 0                bing
# 1                bing
# 2  RANGE_INTERPOLATED
# 3  RANGE_INTERPOLATED
# 4  RANGE_INTERPOLATED

# %%
geocode_cache = dict(
    (d['key'], d) for i, d in geocoded.iterrows()
)

# %% [markdown]
# Identify how many remain unmapped

# %%
df['key'] = df.apply(lambda x: "{}, {}".format(x.city, x.state), axis=1)

# %%
# Added by Steve, how unique are these keys? Semi-unique
df.key.value_counts().head(5)
# Out:
# Vass, NC           6676
# VASS, NC           1078
# CASA GRANDE, AZ     686
# MURRAY, KY          679
# Casa Grande, AZ     446
# Name: key, dtype: int64

# %%
df.sort_values(['city']).head()
# Out:
#          case_number          case_status certification_start_date  \
# 3071   C-08066-08800  Certified - Partial               2008-05-15
# 1341   C-08023-08004     Certified - Full               2008-03-09
# 7599   C-09064-18476     Certified - Full               2009-04-20
# 10847  C-10008-21978     Certified - Full               2010-03-01
# 14891  C-11006-26359     Certified - Full               2011-03-01
#
#        certification_start_year  \
# 3071                     2008.0
# 1341                     2008.0
# 7599                     2009.0
# 10847                    2010.0
# 14891                    2011.0
#
#                                                     city         crop  \
# 3071                    1) WENDEN 2)TONOPAH  3) DATELAND          NaN
# 1341   1.- TONOPAH                           2.- DATE...          NaN
# 7599                             1090 STEVENS RANCH ROAD          NaN
# 10847                                    1561 RAYBURN RD          NaN
# 14891                                    16001 311TH AVE  Cultivating
#
#                                        employer  fiscal_year  \
# 3071                           TEAM PACKING INC         2008
# 1341                           TEAM PACKING INC         2008
# 7599   JOHN E. FIGUEROA D.B.A. RUNNING L. RANCH         2009
# 10847                          ROB MORTON FARMS         2010
# 14891                      AHLEMEIER FARMS INC.         2011
#
#                                                job_title latimes_crop  \
# 3071                                HARVEST WORKER FRUIT          NaN
# 1341                                 FARMWORKER FRUIT II          NaN
# 7599                                    STABLE ATTENDANT          NaN
# 10847  FARMWORKERS AND LABORERS, CROP, NURSERY, AND G...          NaN
# 14891                    AGRICULTURAL EQUIPMENT OPERATOR  Cultivating
#
#       latimes_id master_case  row_number state  workers_certified  \
# 3071   2008-5105       False        5105    AZ                460
# 1341   2008-1630       False        1630    AR                 35
# 7599   2009-4340       False        4340    TX                  5
# 10847  2010-1654       False        1654    KY                  9
# 14891  2011-1602       False        1602    SD                  2
#
#                                                      key
# 3071                1) WENDEN 2)TONOPAH  3) DATELAND, AZ
# 1341   1.- TONOPAH                           2.- DATE...
# 7599                         1090 STEVENS RANCH ROAD, TX
# 10847                                1561 RAYBURN RD, KY
# 14891                                16001 311TH AVE, SD

# %%
# Comment by Steve, these two cell lookup how many bad addresses are untranslatable
not_geocoded = df[~df.key.isin(geocoded.key)]

# %%
print "{:,} of {:,} geocoded ({}%)".format(
    len(df) - len(not_geocoded),
    len(df),
    calculate.percentage(len(df) - len(not_geocoded), len(df))
)
# Out:
# 83,088 of 83,088 geocoded (100.0%)

# %% [markdown]
# Extract the unmapped locations

# %%
unmapped = not_geocoded.groupby(['key']).size().reset_index().rename(columns={0: "count"})

# %%
df_list = list(unmapped.iterrows())

# %%
random.shuffle(df_list)

# %%
# Added by Steve, we don't have any unmapped values
unmapped.size
# Out:
# 0

# %% [markdown]
# Try to geocode them

# %%
@timeout_decorator.timeout(10)
def bingit(key):
    bing = Bing(os.getenv("BING_API_KEY"), timeout=10)
    address = "{}, United States".format(key)
    print "Geocoding {}".format(address)
    try:
        geocode_cache[key]
        print "Already mapped"
        return
    except KeyError:
        pass

    result = bing.geocode(address, exactly_one=False)
    if not result:
        return
    first_result = result[0]

    print "Mapped to {}".format(first_result)
    geocode_cache[key] = first_result
    time.sleep(0.5)

# %%
for i, row in df_list:
    try:
        bingit(row.key)
    except:
        print "TIMEOUT"
        continue

# %% [markdown]
# Merged the newly geocoded locations with the old ones

# %%
def transform_geocode(key, value):
    if isinstance(value, pd.Series):
        return [key, value['geocoder_address'], value['lat'], value['lng'], value['geocoder_type']]
    return [key, value.address, value.latitude, value.longitude, "bing"]

# %%
rows = [transform_geocode(k, v) for k, v in geocode_cache.items()]

# %%
rows.sort(key=lambda x:x[0])

# %% [markdown]
# Save the geocoded locations

# %%
with open("./output/geocoded.csv", 'w') as f:
    w = csv.writer(f)
    w.writerow(["key", "geocoder_address", "lat", "lng", "geocoder_type"])
    w.writerows(rows)

# %% [markdown]
# Merge geocoded points onto cases

# %%
mapped = pd.read_csv("./output/geocoded.csv")

# %%
# Added by Steve, what was `mapped` schema?
mapped.head()
# Out:
#                                                  key  \
# 0               1) WENDEN 2)TONOPAH  3) DATELAND, AZ
# 1  1.- TONOPAH                           2.- DATE...
# 2                        1090 STEVENS RANCH ROAD, TX
# 3                                1561 RAYBURN RD, KY
# 4                                16001 311TH AVE, SD
#
#                                    geocoder_address        lat         lng  \
# 0                       Dateland, AZ, United States  32.799599 -113.540932
# 1                                 AR, United States  34.899921  -92.438873
# 2  1090 Stevens Ranch Rd, Pipe Creek, TX 78063, USA  29.774711  -99.078929
# 3            1561 Rayburn Rd, Murray, KY 42071, USA  36.569439  -88.441078
# 4              16001 311th Ave, Agar, SD 57520, USA  44.896279  -99.939442
#
#         geocoder_type
# 0                bing
# 1                bing
# 2  RANGE_INTERPOLATED
# 3  RANGE_INTERPOLATED
# 4  RANGE_INTERPOLATED

# %%
def create_key(row):
    # Skip any nulls
    if row.city in [np.NaN, 'nan', '']:
        return ''
    elif row.state in [np.NaN, 'nan', '']:
        return ''
    else:
        return "{}, {}".format(row.city, row.state)

# %%
def add_points(name):
    df = pd.read_csv("./output/transformed_{}.csv".format(name))
    df['key'] = df.apply(create_key, axis=1)
    mapped_df = df.merge(mapped, on=["key"], how="left")
    mapped_df.drop('key', axis=1, inplace=True)
    mapped_df.to_csv("./output/geocoded_{}.csv".format(name), index=False, encoding="utf-8")

# %%
# Added by Steve, what is `add_points` doing?
# It's just geocoding the entries

kas = pd.read_csv("./output/transformed_{}.csv".format('sub_cases'))
kas['key'] = kas.apply(create_key, axis=1)
mapped_kas = kas.merge(mapped, on=["key"], how="left")
mapped_kas.drop('key', axis=1, inplace=True)
mapped_kas
# Out:
#               case_number                           case_status  \
# 0           A-07297-04840                      Certified - Full
# 1           A-07297-04840                      Certified - Full
# 2           A-07297-04840                      Certified - Full
# 3           A-07297-04840                      Certified - Full
# 4           A-07297-04840                      Certified - Full
# 5           A-07299-04849                      Certified - Full
# 6           A-07325-04931                      Certified - Full
# 7           A-07327-04937                      Certified - Full
# 8           A-07327-04937                      Certified - Full
# 9           A-07337-04977                      Certified - Full
# 10          A-07337-04977                      Certified - Full
# 11          A-07337-04978                      Certified - Full
# 12          A-07337-04978                      Certified - Full
# 13          A-07337-04978                      Certified - Full
# 14          A-07337-04978                      Certified - Full
# 15          A-07337-04978                      Certified - Full
# 16          A-07337-04978                      Certified - Full
# 17          A-07345-05058                      Certified - Full
# 18          A-07345-05058                      Certified - Full
# 19          A-07348-05075                   Certified - Partial
# 20          A-07348-05075                   Certified - Partial
# 21          A-07353-05140                      Certified - Full
# 22          A-07354-05145                      Certified - Full
# 23          A-07355-05155                      Certified - Full
# 24          A-07361-05176                      Certified - Full
# 4               HORTICULTURAL WORKER   2008-112         112    MS
# 5               FISH HATCHERY WORKER   2008-533         533    MS
# 6                  FARMWORKER, FRUIT   2008-190         190    GA
# 7               HORTICULTURAL WORKER   2008-405         405    MS
# 8               HORTICULTURAL WORKER   2008-406         406    MS
# 9            HORTICULTURAL WORKER II   2008-921         921    NC
# 10           HORTICULTURAL WORKER II   2008-922         922    NC
# 11      FARMWORKER, DIVERSIFIED CROP   2008-681         681    NC
# 12      FARMWORKER, DIVERSIFIED CROP   2008-682         682    NC
# 13      FARMWORKER, DIVERSIFIED CROP   2008-683         683    NC
# 14      FARMWORKER, DIVERSIFIED CROP   2008-684         684    NC
# 15      FARMWORKER, DIVERSIFIED CROP   2008-685         685    NC
# 16      FARMWORKER, DIVERSIFIED CROP   2008-686         686    NC
# 17     FARMWORKER, DIVERSIFIED CROPS   2008-543         543    NY
# 18     FARMWORKER, DIVERSIFIED CROPS   2008-544         544    NY
# 19      FARMWORKER, DIVERSIFIED CROP   2008-464         464    AL
# 20      FARMWORKER, DIVERSIFIED CROP   2008-465         465    AL
# 21        FARM WORKER; FIELD CROP II  2008-1047        1047    KY
# 22           HORTICULTURAL WORKER II   2008-688         688    TN
# 23           FARM WORKER; GENERAL II   2008-541         541    TN
# 24              HORTICULTURAL WORKER   2008-834         834    NY
# 25              HORTICULTURAL WORKER   2008-835         835    NY
# 26              HORTICULTURAL WORKER   2008-836         836    NY
# 27              HORTICULTURAL WORKER   2008-837         837    NY
# 28              HORTICULTURAL WORKER   2008-838         838    NY
# 29              HORTICULTURAL WORKER   2008-839         839    NY
# ...                              ...        ...         ...   ...
# 25954   Farmworker, Diversified Crop  2017-7409        7409    NC
# 25955   Farmworker, Diversified Crop  2017-7410        7410    NC
# 25956   Farmworker, Diversified Crop  2017-7413        7413    NC
# 25957   Farmworker, Diversified Crop  2017-7415        7415    NC
# 25958   Farmworker, Diversified Crop  2017-7416        7416    NC
# 25959   Farmworker, Diversified Crop  2017-7419        7419    NC
# 25960   Farmworker, Diversified Crop  2017-7439        7439    NC
# 25961   Farmworker, Diversified Crop  2017-7440        7440    NC
# 25962   Farmworker, Diversified Crop  2017-7441        7441    NC
# 25963   Farmworker, Diversified Crop  2017-7442        7442    NC
# 25964   Farmworker, Diversified Crop  2017-7438        7438    NC
# 25965   Farmworker, Diversified Crop  2017-7443        7443    NC
# 25966   Farmworker, Diversified Crop  2017-7454        7454    NC
# 25967   Farmworker, Diversified Crop  2017-7455        7455    NC
# 25968         Farm worker / Laborers  2017-7493        7493    WA
# 25969                    Sheepherder  2017-7519        7519    NV
# 25970                    Sheepherder  2017-7530        7530    CA
# 25971                    Sheepherder  2017-7534        7534    UT
# 25972                    Sheepherder  2017-7537        7537    CA
# 25973                    Sheepherder  2017-7540        7540    CA
# 25974                    Sheepherder  2017-7544        7544    CA
# 25975            Farm Worker/Laborer  2017-7547        7547    WA
# 25976                    Sheepherder  2017-7554        7554    UT
# 25977                    Sheepherder  2017-7557        7557    NV
# 25978                  1        Sheep          Orofino, ID, United States
# 25979                  4        Sheep                     Clovis, CA, USA
# 25980                  1       Cattle                 Buhl, ID 83316, USA
# 25981                  9      Tobacco             Vass, NC, United States
# 25982                  5      Tobacco             Vass, NC, United States
# 25983                  1      Tobacco             Vass, NC, United States
#
#              lat         lng geocoder_type
# 0      32.273202  -89.985916   APPROXIMATE
# 1      30.924320  -88.592888          bing
# 2      30.924320  -88.592888          bing
# 3      30.924320  -88.592888          bing
# 4      30.924320  -88.592888          bing
# 5      33.262066  -90.592314   APPROXIMATE
# 6      31.036900  -82.746582          bing
# 7      30.782030  -89.140961          bing
# 8      30.924320  -88.592888          bing
# 9      35.914020  -81.538985   APPROXIMATE
# 10     36.105691  -79.542246   APPROXIMATE
# 11     35.306274  -78.608903   APPROXIMATE
# 12     35.527981  -77.412437          bing
# 13     36.488472  -79.766703   APPROXIMATE
# 14     35.536549  -78.284444   APPROXIMATE
# 15     34.496831  -79.114202   APPROXIMATE
# 16     35.752102  -77.669975   APPROXIMATE
# 17     42.548693  -73.373997   APPROXIMATE
# 18     42.577884  -73.878921   APPROXIMATE
# 19     30.823243  -88.361400   APPROXIMATE
# 20     30.823243  -88.361400   APPROXIMATE
# 21     36.865050  -87.835295   APPROXIMATE
# 22     36.302002  -88.326711   APPROXIMATE
# 23     35.869259  -83.567673          bing
# 24     42.700632  -74.033738   APPROXIMATE
# 25     42.533197  -73.746300   APPROXIMATE
# 26     42.644718  -73.741272          bing
# 27     42.700632  -74.033738   APPROXIMATE
# 28     42.652579  -73.756232   APPROXIMATE
# 29     42.747766  -73.760537   APPROXIMATE
# ...          ...         ...           ...
# 25954  35.257420  -79.282303          bing
# 25955  35.257420  -79.282303          bing
# 25956  35.257420  -79.282303          bing
# 25957  35.257420  -79.282303          bing
# 25958  35.257420  -79.282303          bing
# 25959  35.257420  -79.282303          bing
# 25960  35.257420  -79.282303          bing
# 25961  35.257420  -79.282303          bing
# 25962  35.257420  -79.282303          bing
# 25963  35.257420  -79.282303          bing
# 25964  35.257420  -79.282303          bing
# 25965  35.257420  -79.282303          bing
# 25966  35.257420  -79.282303          bing
# 25967  35.257420  -79.282303          bing
# 25968  46.556210 -120.391968          bing
# 25969  39.512486 -115.960780   APPROXIMATE
# 25970  32.847553 -115.569439   APPROXIMATE
# 25971  41.825489 -111.323952          bing
# 25972  35.373292 -119.018713   APPROXIMATE
# 25973  38.155750 -121.691344   APPROXIMATE
# 25974  39.619604 -122.193873   APPROXIMATE
# 25975  46.604130 -120.507050          bing
# 25976  41.718979 -112.165512          bing
# 25977  41.314595 -116.223469   APPROXIMATE
# 25978  46.479641 -116.255386          bing
# 25979  36.825228 -119.702919   APPROXIMATE
# 25980  42.599071 -114.759495   APPROXIMATE
# 25981  35.257420  -79.282303          bing
# 25982  35.257420  -79.282303          bing
# 25983  35.257420  -79.282303          bing
#
# [25984 rows x 18 columns]

# %%
add_points("master_cases")

# %%
add_points("sub_cases")

# %%
add_points("all_cases")
