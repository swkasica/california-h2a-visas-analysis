# %% [markdown]
# # Transform
#
# Opens and combines [annual H2A visa disclosure data files](https://www.foreignlaborcert.doleta.gov/performancedata.cfm) from the Office of Foreign Labor Certification at the United States Department of Labor.

# %%
import os
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
input_dir = os.path.join(os.getcwd(), 'input')
output_dir = os.path.join(os.getcwd(), 'output')

# %%
# %%capture
os.path.exists(input_dir) or os.mkdirs(intput_dir)
os.path.exists(output_dir) or os.mkdirs(output_dir)

# %% [markdown]
# A crosswalk that standardizes the headers from each year's file to a common schema

# %%
schema = {
    2008: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
        
    ),
    2009: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2010: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2011: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        crop="PRIMARY_CROP",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2012: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        crop="PRIMARY_CROP",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2013: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="ALIEN_WORK_CITY",
        state="ALIEN_WORK_STATE",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2014: dict(
        case_number="CASE_NO",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="WORKSITE_LOCATION_CITY",
        state="WORKSITE_LOCATION_STATE",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2015: dict(
        case_number="CASE_NUMBER",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="WORKSITE_CITY",
        state="WORKSITE_STATE",
        crop="PRIMARY_CROP",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2016: dict(
        case_number="CASE_NUMBER",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="WORKSITE_CITY",
        state="WORKSITE_STATE",
        crop="PRIMARY_CROP",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
    2017: dict(
        case_number="CASE_NUMBER",
        case_status="CASE_STATUS",
        workers_certified="NBR_WORKERS_CERTIFIED",
        employer="EMPLOYER_NAME",
        city="WORKSITE_CITY",
        state="WORKSITE_STATE",
        crop="PRIMARY_CROP",
        job_title="JOB_TITLE",
        certification_start_date="CERTIFICATION_BEGIN_DATE",
    ),
}

# %%
# Added by Steve, see all original column types
pd.read_excel('input/2017.xlsx').dtypes
# Out:
# CASE_NUMBER                         object
# DECISION_DATE               datetime64[ns]
# VISA_CLASS                          object
# CASE_RECEIVED_DATE          datetime64[ns]
# CASE_STATUS                         object
# CERTIFICATION_BEGIN_DATE    datetime64[ns]
# CERTIFICATION_END_DATE      datetime64[ns]
# PRIMARY/SUB                         object
# EMPLOYER_NAME                       object
# EMPLOYER_ADDRESS1                   object
# EMPLOYER_ADDRESS2                   object
# EMPLOYER_CITY                       object
# EMPLOYER_STATE                      object
# EMPLOYER_POSTAL_CODE                object
# EMPLOYER_COUNTRY                    object
# EMPLOYER_PROVINCE                   object
# EMPLOYER_PHONE                      object
# EMPLOYER_PHONE_EXT                 float64
# LAWFIRM_NAME                        object
# AGENT_ATTORNEY_NAME                 object
# AGENT_ATTORNEY_CITY                 object
# AGENT_ATTORNEY_STATE                object
# JOB_TITLE                           object
# SOC_CODE                            object
# SOC_TITLE                           object
# PRIMARY_CROP                        object
# NAICS_CODE                         float64
# NBR_WORKERS_REQUESTED              float64
# NBR_WORKERS_CERTIFIED              float64
# FULL_TIME_POSITION                  object
# NATURE_OF_TEMPORARY_NEED            object
# BASIC_NUMBER_OF_HOURS              float64
# HOURLY_WORK_SCHEDULE_AM             object
# HOURLY_WORK_SCHEDULE_PM             object
# BASIC_RATE_OF_PAY                  float64
# BASIC_UNIT_OF_PAY                   object
# OVERTIME_RATE_FROM                 float64
# OVERTIME_RATE_TO                   float64
# OVERTIME_PAY_RANGE_UNIT             object
# SUPERVISE_OTHER_EMP                 object
# SUPERVISE_HOW_MANY                 float64
# EDUCATION_LEVEL                     object
# OTHER_EDU                           object
# MAJOR                               object
# SECOND_DIPLOMA                      object
# SECOND_DIPLOMA_MAJOR               float64
# TRAINING_REQ                        object
# NUM_MONTHS_TRAINING                float64
# NAME_REQD_TRAINING                  object
# EMP_EXPERIENCE_REQD                 object
# EMP_EXP_NUM_MONTHS                 float64
# WORKSITE_CITY                       object
# WORKSITE_STATE                      object
# WORKSITE_POSTAL_CODE                object
# OTHER_WORKSITE_LOCATION             object
# ORGANIZATION_FLAG                   object
# SWA_NAME                            object
# JOB_IDNUMBER                        object
# JOB_START_DATE              datetime64[ns]
# JOB_END_DATE                datetime64[ns]
# dtype: object

# %%
def transform_xls(year):
    """
    Transforms the H2A visa data from the provided year.
    
    Returns it cleaned up, deduped and standardized for consolidation with other years.
    """
    print("Transforming {} data".format(year))

    # Open the raw file
    input_path = os.path.join(
        input_dir,
        "{}.xlsx".format(year)
    )
    df = pd.read_excel(input_path)
    
    # Pull the schema for this year
    s = schema[year]

    # Reverse the schemaand standardize the column names
    i = {v: k for k, v in s.iteritems()}
    df = df.rename(columns=i)
    
    # Trim down to just the columns we want to keep
    trimmed = df[s.keys()]

    # Add the fiscal year from the file name
    trimmed['fiscal_year'] = year
    
    # Add a column with the calendar year where the jobs were certified
    trimmed.certification_start_date = pd.to_datetime(trimmed.certification_start_date)
    trimmed['certification_start_year'] = trimmed.apply(lambda x: x.certification_start_date.year, axis=1)
    
    # Trim applications from outside the time range we want to analyze
    trimmed = trimmed[
        (trimmed.certification_start_year > 2007) &
        (trimmed.certification_start_year < 2018)
    ]
   
    # Add incremental id
    trimmed['row_number'] = range(len(trimmed))

    # Combine that with the fiscal year into a unique id
    trimmed['latimes_id'] = trimmed.apply(lambda x: "{}-{}".format(x.fiscal_year, x.row_number), axis=1)

    # A little clean up on numbers
    trimmed.workers_certified.fillna(0, inplace=True)
    trimmed.workers_certified = trimmed.workers_certified.astype(int)
    
    # Drop duplicate case records, as prescribed by the DOL.
    ## They say, "When analyzing H-2A program use, it is recommended to
    ## use the total number of workers certified (NBR_WORKERS_CERTIFIED)
    ## listed on the "master" record (i.e., the first employer record
    ## listed in the series of duplicate case numbers), which
    ## represents the total unique number of workers certified for
    ## the entire H-2A application, including all of the "sub" employer records.
    
    # HOWEVER! Close examination of the data shows that we cannot depend on the master
    # master record coming first in the spreadsheets.
    
    # On the advice of the DOL, we will resort the data so that the record
    # with the maximum workers certified comes first and will then infer
    # that is must be the parent record.
    dupes = trimmed.groupby("case_number").filter(lambda x: len(x) > 1).sort_values(
        ["case_number", "workers_certified"],
        ascending=[True, False]
    )
    master_cases = dupes.drop_duplicates("case_number", keep="first")
    master_cases['master_case'] = True
    sub_cases = dupes[~dupes['latimes_id'].isin(master_cases.latimes_id)]
    deduped = trimmed[~trimmed.case_number.isin(dupes.case_number)]
    deduped['master_case'] = False
    deduped = deduped.append(master_cases)
    
    # Filter it down to only those applications that were approved
    approved_status_list = [
        'DETERMINATION ISSUED - CERTIFICATION',
        'DETERMINATION ISSUED - PARTIAL CERTIFICATION',
        'Certified - Full',
        'Certified - Partial',
        # According to interview with a DOL official,
        # the expired certifications should be included.
        # They are only marked that way due to a bookkeeping error
        # when the records are pulled for public disclosure.
        'DETERMINATION ISSUED - CERTIFICATION EXPIRED',
        'DETERMINATION ISSUED - PARTIAL CERTIFICATION EXPIRED',
    ]
    certified = deduped[deduped.case_status.isin(approved_status_list)]
    sub_cases = sub_cases[sub_cases.case_status.isin(approved_status_list)]
       
    # Pass the DataFrames back
    return certified, sub_cases

# %%
# Added by Steve

# Open the raw file
input_path = os.path.join(input_dir, "{}.xlsx".format('2012'))

df = pd.read_excel(input_path)

# Pull the schema for this year
s = schema[2012]

# Reverse the schemaand standardize the column names
i = {v: k for k, v in s.items()}
df = df.rename(columns=i)

# Trim down to just the columns we want to keep
trimmed = df[s.keys()]

# Add the fiscal year from the file name
trimmed['fiscal_year'] = '2012'

# Add a column with the calendar year where the jobs were certified
trimmed.certification_start_date = pd.to_datetime(trimmed.certification_start_date)
trimmed['certification_start_year'] = trimmed.apply(lambda x: x.certification_start_date.year, axis=1)

# Trim applications from outside the time range we want to analyze
trimmed = trimmed[
    (trimmed.certification_start_year > 2007) &
    (trimmed.certification_start_year < 2018)
]

# Add incremental id
trimmed['row_number'] = range(len(trimmed))

# Combine that with the fiscal year into a unique id
trimmed['latimes_id'] = trimmed.apply(lambda x: "{}-{}".format(x.fiscal_year, x.row_number), axis=1)

# A little clean up on numbers
trimmed.workers_certified.fillna(0, inplace=True)
trimmed.workers_certified = trimmed.workers_certified.astype(int)

# Drop duplicate case records, as prescribed by the DOL.
## They say, "When analyzing H-2A program use, it is recommended to
## use the total number of workers certified (NBR_WORKERS_CERTIFIED)
## listed on the "master" record (i.e., the first employer record
## listed in the series of duplicate case numbers), which
## represents the total unique number of workers certified for
## the entire H-2A application, including all of the "sub" employer records.

# HOWEVER! Close examination of the data shows that we cannot depend on the master
# master record coming first in the spreadsheets.

# On the advice of the DOL, we will resort the data so that the record
# with the maximum workers certified comes first and will then infer
# that is must be the parent record.
dupes = trimmed.groupby("case_number").filter(lambda x: len(x) > 1).sort_values(
    ["case_number", "workers_certified"],
    ascending=[True, False]
)

master_cases = dupes.drop_duplicates("case_number", keep="first")
master_cases['master_case'] = True
sub_cases = dupes[~dupes['latimes_id'].isin(master_cases.latimes_id)]
deduped = trimmed[~trimmed.case_number.isin(dupes.case_number)]
deduped['master_case'] = False
deduped = deduped.append(master_cases)

# Filter it down to only those applications that were approved
approved_status_list = [
    'DETERMINATION ISSUED - CERTIFICATION',
    'DETERMINATION ISSUED - PARTIAL CERTIFICATION',
    'Certified - Full',
    'Certified - Partial',
    # According to interview with a DOL official,
    # the expired certifications should be included.
    # They are only marked that way due to a bookkeeping error
    # when the records are pulled for public disclosure.
    'DETERMINATION ISSUED - CERTIFICATION EXPIRED',
    'DETERMINATION ISSUED - PARTIAL CERTIFICATION EXPIRED',
]
certified = deduped[deduped.case_status.isin(approved_status_list)]
sub_cases = sub_cases[sub_cases.case_status.isin(approved_status_list)]

# %%
# Added by Steve,
trimmed.groupby('case_number').filter(lambda x: len(x) > 1).sort_values(['case_number', 'workers_certified'], ascending=[True, False])
# Out:
#                   city certification_start_date                     crop  \
# 1       SALT LAKE CITY               2011-07-10              Sheepherder
# 2              GOODING               2011-07-10              Sheepherder
# 3                SMITH               2011-07-10              Sheepherder
# 4              VISALIA               2011-07-10              Sheepherder
# 5                CAREY               2011-07-10              Sheepherder
# 6                DIXON               2011-07-10              Sheepherder
# 7           WHITE BIRD               2011-07-10              Sheepherder
# 8                 PAUL               2011-07-10              Sheepherder
# 9                 PAUL               2011-07-10              Sheepherder
# 10              IMLAYS               2011-07-10              Sheepherder
# 11           PENDLETON               2011-07-10              Sheepherder
# 12              MEADOW               2011-07-10              Sheepherder
# 13            EVANSTON               2011-07-10              Sheepherder
# 14         PASO ROBLES               2011-07-10              Sheepherder
# 15           LOS BANOS               2011-07-10              Sheepherder
# 16             BRAWLEY               2011-07-10              Sheepherder
# 17         BAKERSFIELD               2011-07-10              Sheepherder
# 18         PASO ROBLES               2011-07-10              Sheepherder
# 19               DIXON               2011-07-10              Sheepherder
# 20         BAKERSFIELD               2011-07-10              Sheepherder
# 21            SOMERSON               2011-07-10              Sheepherder
# 22            MONTROSE               2011-07-10              Sheepherder
# 23         MONTE VISTA               2011-07-10              Sheepherder
# 24    MILTON-FREEWATER               2011-07-10              Sheepherder
# 25          BAKER CITY               2011-07-10              Sheepherder
# 26              MORONI               2011-07-10              Sheepherder
# 27             HENEFER               2011-07-10              Sheepherder
# 28         BROWNSVILLE               2011-07-10              Sheepherder
# 35      SALT LAKE CITY               2011-11-10              Sheepherder
# 36              WILDER               2011-11-10              Sheepherder
# ...                ...                      ...                      ...
# 7914              VASS               2012-10-15  Nurseries & Greenhouses
# 7957              VASS               2012-10-25          Christmas Trees
# 7958              VASS               2012-10-25          Christmas Trees
# 7959              VASS               2012-10-25          Christmas Trees
# 7960              VASS               2012-10-25          Christmas Trees
# 7961              VASS               2012-10-25          Christmas Trees
# 7962              VASS               2012-10-25          Christmas Trees
# 7963              VASS               2012-10-25          Christmas Trees
# 7964              VASS               2012-10-25          Christmas Trees
# 7965              VASS               2012-10-25          Christmas Trees
# 7966              VASS               2012-10-25          Christmas Trees
# 7967              VASS               2012-10-25          Christmas Trees
# 7968              VASS               2012-10-25          Christmas Trees
# 7969              VASS               2012-10-25          Christmas Trees
# 7970              VASS               2012-10-25          Christmas Trees
# 7971              VASS               2012-10-25          Christmas Trees
# 7972              VASS               2012-10-25          Christmas Trees
# 7973              VASS               2012-10-25          Christmas Trees
# 7974              VASS               2012-10-25          Christmas Trees
# 7975              VASS               2012-10-25          Christmas Trees
# 7976              VASS               2012-10-25          Christmas Trees
# 7977              VASS               2012-10-25          Christmas Trees
# 7978              VASS               2012-10-25          Christmas Trees
# 7979              VASS               2012-10-25          Christmas Trees
# 7980              VASS               2012-10-25          Christmas Trees
# 7981              VASS               2012-10-25          Christmas Trees
# 7982              VASS               2012-10-25          Christmas Trees
# 7983              VASS               2012-10-25          Christmas Trees
# 7984              VASS               2012-10-25          Christmas Trees
# 7985              VASS               2012-10-25          Christmas Trees
#
#                                              employer state  \
# 1                           WESTERN RANGE ASSOCIATION    UT
# 2                                       FAULKNER LAND    ID
# 3                                              F.I.M.    NV
# 4                                     I.O.U. SHEEP CO    CA
# 5                                      FLAT TOP SHEEP    ID
# 6                        CLIFF DETAR & MARTIN RONAYNE    CA
# 7                               RAY E. HOLES / LAZY H    ID
# 8                                J & A PHILLIPS RANCH    ID
# 9                                      FORREST ARTHUR    ID
# 10                                      JOHN OLAGARAY    NV
# 11                                  GILLESPIE GRAZING    OR
# 12                             VEAL BLACK ANGUS RANCH    SD
# 13                                            JRB LLC    WY
# 14                                    MARTIN JAUREGUY    CA
# 15                                AMADOR ZABALBEASCOA    CA
# 16                                  MARTIN AUZA SHEEP    CA
# 17                                HEBER-RENO SHEEP CO    CA
# 18                                      J.B. JAUREGUY    CA
# 19                           ROBERT OR DEBRANN MCGREW    CA
# 20                                     EL TEJON SHEEP    CA
# 21                                   ANTONIO SARRATEA    AZ
# 22                                 COOPER SHEEP RANCH    CO
# 23                                      KLECKER FARMS    CO
# 24                                        ERIC HARLOW    OR
# 25                                     JACOBS RANCHES    OR
# 26                                        BOX L RANCH    UT
# 27                                     H.R. LIVESTOCK    UT
# 28                              REED & ROBYN ANDERSON    OR
# 35                          WESTERN RANGE ASSOCIATION    UT
# 36                                       FRANK SHIRTS    ID
# ...                                               ...   ...
# 7914  NORTH CAROLINA GROWERS ASSOCIATION, INC. (NCGA)    NC
# 7957  NORTH CAROLINA GROWERS ASSOCIATION, INC. (NCGA)    NC
# 7958                     MARK JOHNSTON CHRIST SHUMATE    NC
# 7959                     JAMES M. & CHERIE S. SHATLEY    NC
# 7960                                   MATTHEW HORNEY    NC
# 7961                                   GRAHAM FERRELL    NC
# 7962                              GREG & JAMES SEXTON    NC
# 7963                                   ROGER CRITCHER    NC
# 7964                                   RENEE CAMPBELL    NC
# 7965                                       RUSTY BARR    NC
# 7966                                  WILLIAM M. PATE    NC
# 7967                                      DALE HUDLER    NC
# 7968                                    DAVID CARTNER    NC
# 7969                             PAUL SPAULDING SMITH    NC
# 7970                                   EARL DEAL, JR.    NC
# 7971                         BOBBY EUGENE DANIELS JR.    NC
# 7972                                  WILEY S. GIMLIN    NC
# 7973                               CARROLL E. GARLAND    NC
# 7974                                    SAMUEL CHURCH    NC
# 7975                                 DOUGLAS R. CLARK    NC
# 7976                                     ANNA TRIVETT    NC
# 7977                                   HARRY B. YATES    NC
# 7978                      JOHN, HELEN & BRYAN WAGONER    NC
# 7979                                 CLAY CUTHBERTSON    NC
# 7980                                   WAYNE E. VANCE    NC
# 7981                                JOHN C. DELLINGER    NC
# 7982                                 DANNY G. BULESON    NC
# 7983                                    SAMUEL STOREY    NC
# 7984                                     CLINE CHURCH    NC
# 7985                                  JAMES B. BENSON    NC
#
#       workers_certified    case_number       case_status  \
# 1                    45  C-11130-29271  Certified - Full
# 2                     4  C-11130-29271  Certified - Full
# 3                     4  C-11130-29271  Certified - Full
# 4                     3  C-11130-29271  Certified - Full
# 5                     3  C-11130-29271  Certified - Full
# 6                     2  C-11130-29271  Certified - Full
# 7                     2  C-11130-29271  Certified - Full
# 8                     2  C-11130-29271  Certified - Full
# 9                     2  C-11130-29271  Certified - Full
# 10                    2  C-11130-29271  Certified - Full
# 11                    2  C-11130-29271  Certified - Full
# 12                    2  C-11130-29271  Certified - Full
# 13                    2  C-11130-29271  Certified - Full
# 14                    1  C-11130-29271  Certified - Full
# 15                    1  C-11130-29271  Certified - Full
# 16                    1  C-11130-29271  Certified - Full
# 17                    1  C-11130-29271  Certified - Full
# 18                    1  C-11130-29271  Certified - Full
# 19                    1  C-11130-29271  Certified - Full
# 20                    1  C-11130-29271  Certified - Full
# 21                    1  C-11130-29271  Certified - Full
# 22                    1  C-11130-29271  Certified - Full
# 23                    1  C-11130-29271  Certified - Full
# 24                    1  C-11130-29271  Certified - Full
# 25                    1  C-11130-29271  Certified - Full
# 26                    1  C-11130-29271  Certified - Full
# 27                    1  C-11130-29271  Certified - Full
# 28                    1  C-11130-29271  Certified - Full
# 35                  116  C-11245-29987  Certified - Full
# 36                   27  C-11245-29987  Certified - Full
# ...                 ...            ...               ...
# 7914                 24  C-12230-35471  Certified - Full
# 7957                595  C-12242-35516  Certified - Full
# 7958                 60  C-12242-35516  Certified - Full
# 7959                 59  C-12242-35516  Certified - Full
# 7960                 48  C-12242-35516  Certified - Full
# 7961                 46  C-12242-35516  Certified - Full
# 7962                 46  C-12242-35516  Certified - Full
# 7963                 42  C-12242-35516  Certified - Full
# 7964                 33  C-12242-35516  Certified - Full
# 7965                 28  C-12242-35516  Certified - Full
# 7966                 28  C-12242-35516  Certified - Full
# 7967                 27  C-12242-35516  Certified - Full
# 7968                 20  C-12242-35516  Certified - Full
# 7969                 20  C-12242-35516  Certified - Full
# 7970                 18  C-12242-35516  Certified - Full
# 7971                 16  C-12242-35516  Certified - Full
# 7972                 16  C-12242-35516  Certified - Full
# 7973                 15  C-12242-35516  Certified - Full
# 7974                 10  C-12242-35516  Certified - Full
# 7975                 10  C-12242-35516  Certified - Full
# 7976                  9  C-12242-35516  Certified - Full
# 7977                  9  C-12242-35516  Certified - Full
# 7978                  8  C-12242-35516  Certified - Full
# 7979                  7  C-12242-35516  Certified - Full
# 7980                  7  C-12242-35516  Certified - Full
# 7981                  5  C-12242-35516  Certified - Full
# 7982                  3  C-12242-35516  Certified - Full
# 7983                  3  C-12242-35516  Certified - Full
# 7984                  2  C-12242-35516  Certified - Full
# 7985                  1  C-12242-35516  Certified - Full
#
#                                    job_title fiscal_year  \
# 1        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 2        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 3        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 4        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 5        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 6        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 7        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 8        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 9        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 10       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 11       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 12       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 13       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 14       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 15       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 16       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 17       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 18       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 19       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 20       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 21       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 22       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 23       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 24       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 25       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 26       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 27       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 28       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 35       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 36       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# ...                                      ...         ...
# 7914  FARMWORKER; NURSERY CROP-HORTICULTURAL        2012
# 7957            FARMWORKER; DIVERSIFIED CROP        2012
# 7958            FARMWORKER; DIVERSIFIED CROP        2012
# 7959            FARMWORKER; DIVERSIFIED CROP        2012
# 7960            FARMWORKER; DIVERSIFIED CROP        2012
# 7961            FARMWORKER; DIVERSIFIED CROP        2012
# 7962            FARMWORKER; DIVERSIFIED CROP        2012
# 7963            FARMWORKER; DIVERSIFIED CROP        2012
# 7964            FARMWORKER; DIVERSIFIED CROP        2012
# 7965            FARMWORKER; DIVERSIFIED CROP        2012
# 7966            FARMWORKER; DIVERSIFIED CROP        2012
# 7967            FARMWORKER; DIVERSIFIED CROP        2012
# 7968            FARMWORKER; DIVERSIFIED CROP        2012
# 7969            FARMWORKER; DIVERSIFIED CROP        2012
# 7970            FARMWORKER; DIVERSIFIED CROP        2012
# 7971            FARMWORKER; DIVERSIFIED CROP        2012
# 7972            FARMWORKER; DIVERSIFIED CROP        2012
# 7973            FARMWORKER; DIVERSIFIED CROP        2012
# 7974            FARMWORKER; DIVERSIFIED CROP        2012
# 7975            FARMWORKER; DIVERSIFIED CROP        2012
# 7976            FARMWORKER; DIVERSIFIED CROP        2012
# 7977            FARMWORKER; DIVERSIFIED CROP        2012
# 7978            FARMWORKER; DIVERSIFIED CROP        2012
# 7979            FARMWORKER; DIVERSIFIED CROP        2012
# 7980            FARMWORKER; DIVERSIFIED CROP        2012
# 7981            FARMWORKER; DIVERSIFIED CROP        2012
# 7982            FARMWORKER; DIVERSIFIED CROP        2012
# 7983            FARMWORKER; DIVERSIFIED CROP        2012
# 7984            FARMWORKER; DIVERSIFIED CROP        2012
# 7985            FARMWORKER; DIVERSIFIED CROP        2012
#
#       certification_start_year  row_number latimes_id
# 1                       2011.0           1     2012-1
# 2                       2011.0           2     2012-2
# 3                       2011.0           3     2012-3
# 4                       2011.0           4     2012-4
# 5                       2011.0           5     2012-5
# 6                       2011.0           6     2012-6
# 7                       2011.0           7     2012-7
# 8                       2011.0           8     2012-8
# 9                       2011.0           9     2012-9
# 10                      2011.0          10    2012-10
# 11                      2011.0          11    2012-11
# 12                      2011.0          12    2012-12
# 13                      2011.0          13    2012-13
# 14                      2011.0          14    2012-14
# 15                      2011.0          15    2012-15
# 16                      2011.0          16    2012-16
# 17                      2011.0          17    2012-17
# 18                      2011.0          18    2012-18
# 19                      2011.0          19    2012-19
# 20                      2011.0          20    2012-20
# 21                      2011.0          21    2012-21
# 22                      2011.0          22    2012-22
# 23                      2011.0          23    2012-23
# 24                      2011.0          24    2012-24
# 25                      2011.0          25    2012-25
# 26                      2011.0          26    2012-26
# 27                      2011.0          27    2012-27
# 28                      2011.0          28    2012-28
# 35                      2011.0          34    2012-34
# 36                      2011.0          35    2012-35
# ...                        ...         ...        ...
# 7914                    2012.0        7727  2012-7727
# 7957                    2012.0        7765  2012-7765
# 7958                    2012.0        7766  2012-7766
# 7959                    2012.0        7767  2012-7767
# 7960                    2012.0        7768  2012-7768
# 7961                    2012.0        7769  2012-7769
# 7962                    2012.0        7770  2012-7770
# 7963                    2012.0        7771  2012-7771
# 7964                    2012.0        7772  2012-7772
# 7965                    2012.0        7773  2012-7773
# 7966                    2012.0        7774  2012-7774
# 7967                    2012.0        7775  2012-7775
# 7968                    2012.0        7776  2012-7776
# 7969                    2012.0        7777  2012-7777
# 7970                    2012.0        7778  2012-7778
# 7971                    2012.0        7779  2012-7779
# 7972                    2012.0        7780  2012-7780
# 7973                    2012.0        7781  2012-7781
# 7974                    2012.0        7782  2012-7782
# 7975                    2012.0        7783  2012-7783
# 7976                    2012.0        7784  2012-7784
# 7977                    2012.0        7785  2012-7785
# 7978                    2012.0        7786  2012-7786
# 7979                    2012.0        7787  2012-7787
# 7980                    2012.0        7788  2012-7788
# 7981                    2012.0        7789  2012-7789
# 7982                    2012.0        7790  2012-7790
# 7983                    2012.0        7791  2012-7791
# 7984                    2012.0        7792  2012-7792
# 7985                    2012.0        7793  2012-7793
#
# [2810 rows x 13 columns]

# %%
# Added by Steve

dupes[~dupes['latimes_id'].isin(master_cases.latimes_id)]
# Out:
#                   city certification_start_date                     crop  \
# 2              GOODING               2011-07-10              Sheepherder
# 3                SMITH               2011-07-10              Sheepherder
# 4              VISALIA               2011-07-10              Sheepherder
# 5                CAREY               2011-07-10              Sheepherder
# 6                DIXON               2011-07-10              Sheepherder
# 7           WHITE BIRD               2011-07-10              Sheepherder
# 8                 PAUL               2011-07-10              Sheepherder
# 9                 PAUL               2011-07-10              Sheepherder
# 10              IMLAYS               2011-07-10              Sheepherder
# 11           PENDLETON               2011-07-10              Sheepherder
# 12              MEADOW               2011-07-10              Sheepherder
# 13            EVANSTON               2011-07-10              Sheepherder
# 14         PASO ROBLES               2011-07-10              Sheepherder
# 15           LOS BANOS               2011-07-10              Sheepherder
# 16             BRAWLEY               2011-07-10              Sheepherder
# 17         BAKERSFIELD               2011-07-10              Sheepherder
# 18         PASO ROBLES               2011-07-10              Sheepherder
# 19               DIXON               2011-07-10              Sheepherder
# 20         BAKERSFIELD               2011-07-10              Sheepherder
# 21            SOMERSON               2011-07-10              Sheepherder
# 22            MONTROSE               2011-07-10              Sheepherder
# 23         MONTE VISTA               2011-07-10              Sheepherder
# 24    MILTON-FREEWATER               2011-07-10              Sheepherder
# 25          BAKER CITY               2011-07-10              Sheepherder
# 26              MORONI               2011-07-10              Sheepherder
# 27             HENEFER               2011-07-10              Sheepherder
# 28         BROWNSVILLE               2011-07-10              Sheepherder
# 36              WILDER               2011-11-10              Sheepherder
# 37             GOODING               2011-11-10              Sheepherder
# 38               CRAIG               2011-11-10              Sheepherder
# ...                ...                      ...                      ...
# 7902              VASS               2012-08-17                      Hay
# 7914              VASS               2012-10-15  Nurseries & Greenhouses
# 7958              VASS               2012-10-25          Christmas Trees
# 7959              VASS               2012-10-25          Christmas Trees
# 7960              VASS               2012-10-25          Christmas Trees
# 7961              VASS               2012-10-25          Christmas Trees
# 7962              VASS               2012-10-25          Christmas Trees
# 7963              VASS               2012-10-25          Christmas Trees
# 7964              VASS               2012-10-25          Christmas Trees
# 7965              VASS               2012-10-25          Christmas Trees
# 7966              VASS               2012-10-25          Christmas Trees
# 7967              VASS               2012-10-25          Christmas Trees
# 7968              VASS               2012-10-25          Christmas Trees
# 7969              VASS               2012-10-25          Christmas Trees
# 7970              VASS               2012-10-25          Christmas Trees
# 7971              VASS               2012-10-25          Christmas Trees
# 7972              VASS               2012-10-25          Christmas Trees
# 7973              VASS               2012-10-25          Christmas Trees
# 7974              VASS               2012-10-25          Christmas Trees
# 7975              VASS               2012-10-25          Christmas Trees
# 7976              VASS               2012-10-25          Christmas Trees
# 7977              VASS               2012-10-25          Christmas Trees
# 7978              VASS               2012-10-25          Christmas Trees
# 7979              VASS               2012-10-25          Christmas Trees
# 7980              VASS               2012-10-25          Christmas Trees
# 7981              VASS               2012-10-25          Christmas Trees
# 7982              VASS               2012-10-25          Christmas Trees
# 7983              VASS               2012-10-25          Christmas Trees
# 7984              VASS               2012-10-25          Christmas Trees
# 7985              VASS               2012-10-25          Christmas Trees
#
#                                              employer state  \
# 2                                       FAULKNER LAND    ID
# 3                                              F.I.M.    NV
# 4                                     I.O.U. SHEEP CO    CA
# 5                                      FLAT TOP SHEEP    ID
# 6                        CLIFF DETAR & MARTIN RONAYNE    CA
# 7                               RAY E. HOLES / LAZY H    ID
# 8                                J & A PHILLIPS RANCH    ID
# 9                                      FORREST ARTHUR    ID
# 10                                      JOHN OLAGARAY    NV
# 11                                  GILLESPIE GRAZING    OR
# 12                             VEAL BLACK ANGUS RANCH    SD
# 13                                            JRB LLC    WY
# 14                                    MARTIN JAUREGUY    CA
# 15                                AMADOR ZABALBEASCOA    CA
# 16                                  MARTIN AUZA SHEEP    CA
# 17                                HEBER-RENO SHEEP CO    CA
# 18                                      J.B. JAUREGUY    CA
# 19                           ROBERT OR DEBRANN MCGREW    CA
# 20                                     EL TEJON SHEEP    CA
# 21                                   ANTONIO SARRATEA    AZ
# 22                                 COOPER SHEEP RANCH    CO
# 23                                      KLECKER FARMS    CO
# 24                                        ERIC HARLOW    OR
# 25                                     JACOBS RANCHES    OR
# 26                                        BOX L RANCH    UT
# 27                                     H.R. LIVESTOCK    UT
# 28                              REED & ROBYN ANDERSON    OR
# 36                                       FRANK SHIRTS    ID
# 37                          FAULKNER LAND & LIVESTOCK    ID
# 38                        NOTTINGHAM LAND & LIVESTOCK    CO
# ...                                               ...   ...
# 7902         NORTH CAROLINA GROWERS ASSOCIATION, INC.    NC
# 7914  NORTH CAROLINA GROWERS ASSOCIATION, INC. (NCGA)    NC
# 7958                     MARK JOHNSTON CHRIST SHUMATE    NC
# 7959                     JAMES M. & CHERIE S. SHATLEY    NC
# 7960                                   MATTHEW HORNEY    NC
# 7961                                   GRAHAM FERRELL    NC
# 7962                              GREG & JAMES SEXTON    NC
# 7963                                   ROGER CRITCHER    NC
# 7964                                   RENEE CAMPBELL    NC
# 7965                                       RUSTY BARR    NC
# 7966                                  WILLIAM M. PATE    NC
# 7967                                      DALE HUDLER    NC
# 7968                                    DAVID CARTNER    NC
# 7969                             PAUL SPAULDING SMITH    NC
# 7970                                   EARL DEAL, JR.    NC
# 7971                         BOBBY EUGENE DANIELS JR.    NC
# 7972                                  WILEY S. GIMLIN    NC
# 7973                               CARROLL E. GARLAND    NC
# 7974                                    SAMUEL CHURCH    NC
# 7975                                 DOUGLAS R. CLARK    NC
# 7976                                     ANNA TRIVETT    NC
# 7977                                   HARRY B. YATES    NC
# 7978                      JOHN, HELEN & BRYAN WAGONER    NC
# 7979                                 CLAY CUTHBERTSON    NC
# 7980                                   WAYNE E. VANCE    NC
# 7981                                JOHN C. DELLINGER    NC
# 7982                                 DANNY G. BULESON    NC
# 7983                                    SAMUEL STOREY    NC
# 7984                                     CLINE CHURCH    NC
# 7985                                  JAMES B. BENSON    NC
#
#       workers_certified    case_number       case_status  \
# 2                     4  C-11130-29271  Certified - Full
# 3                     4  C-11130-29271  Certified - Full
# 4                     3  C-11130-29271  Certified - Full
# 5                     3  C-11130-29271  Certified - Full
# 6                     2  C-11130-29271  Certified - Full
# 7                     2  C-11130-29271  Certified - Full
# 8                     2  C-11130-29271  Certified - Full
# 9                     2  C-11130-29271  Certified - Full
# 10                    2  C-11130-29271  Certified - Full
# 11                    2  C-11130-29271  Certified - Full
# 12                    2  C-11130-29271  Certified - Full
# 13                    2  C-11130-29271  Certified - Full
# 14                    1  C-11130-29271  Certified - Full
# 15                    1  C-11130-29271  Certified - Full
# 16                    1  C-11130-29271  Certified - Full
# 17                    1  C-11130-29271  Certified - Full
# 18                    1  C-11130-29271  Certified - Full
# 19                    1  C-11130-29271  Certified - Full
# 20                    1  C-11130-29271  Certified - Full
# 21                    1  C-11130-29271  Certified - Full
# 22                    1  C-11130-29271  Certified - Full
# 23                    1  C-11130-29271  Certified - Full
# 24                    1  C-11130-29271  Certified - Full
# 25                    1  C-11130-29271  Certified - Full
# 26                    1  C-11130-29271  Certified - Full
# 27                    1  C-11130-29271  Certified - Full
# 28                    1  C-11130-29271  Certified - Full
# 36                   27  C-11245-29987  Certified - Full
# 37                    8  C-11245-29987  Certified - Full
# 38                    6  C-11245-29987  Certified - Full
# ...                 ...            ...               ...
# 7902                 16  C-12226-35456  Certified - Full
# 7914                 24  C-12230-35471  Certified - Full
# 7958                 60  C-12242-35516  Certified - Full
# 7959                 59  C-12242-35516  Certified - Full
# 7960                 48  C-12242-35516  Certified - Full
# 7961                 46  C-12242-35516  Certified - Full
# 7962                 46  C-12242-35516  Certified - Full
# 7963                 42  C-12242-35516  Certified - Full
# 7964                 33  C-12242-35516  Certified - Full
# 7965                 28  C-12242-35516  Certified - Full
# 7966                 28  C-12242-35516  Certified - Full
# 7967                 27  C-12242-35516  Certified - Full
# 7968                 20  C-12242-35516  Certified - Full
# 7969                 20  C-12242-35516  Certified - Full
# 7970                 18  C-12242-35516  Certified - Full
# 7971                 16  C-12242-35516  Certified - Full
# 7972                 16  C-12242-35516  Certified - Full
# 7973                 15  C-12242-35516  Certified - Full
# 7974                 10  C-12242-35516  Certified - Full
# 7975                 10  C-12242-35516  Certified - Full
# 7976                  9  C-12242-35516  Certified - Full
# 7977                  9  C-12242-35516  Certified - Full
# 7978                  8  C-12242-35516  Certified - Full
# 7979                  7  C-12242-35516  Certified - Full
# 7980                  7  C-12242-35516  Certified - Full
# 7981                  5  C-12242-35516  Certified - Full
# 7982                  3  C-12242-35516  Certified - Full
# 7983                  3  C-12242-35516  Certified - Full
# 7984                  2  C-12242-35516  Certified - Full
# 7985                  1  C-12242-35516  Certified - Full
#
#                                    job_title fiscal_year  \
# 2        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 3        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 4        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 5        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 6        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 7        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 8        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 9        FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 10       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 11       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 12       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 13       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 14       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 15       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 16       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 17       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 18       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 19       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 20       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 21       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 22       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 23       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 24       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 25       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 26       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 27       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 28       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 36       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 37       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# 38       FARMWORKERS, FARM AND RANCH ANIMALS        2012
# ...                                      ...         ...
# 7902            FARMWORKER; DIVERSIFIED CROP        2012
# 7914  FARMWORKER; NURSERY CROP-HORTICULTURAL        2012
# 7958            FARMWORKER; DIVERSIFIED CROP        2012
# 7959            FARMWORKER; DIVERSIFIED CROP        2012
# 7960            FARMWORKER; DIVERSIFIED CROP        2012
# 7961            FARMWORKER; DIVERSIFIED CROP        2012
# 7962            FARMWORKER; DIVERSIFIED CROP        2012
# 7963            FARMWORKER; DIVERSIFIED CROP        2012
# 7964            FARMWORKER; DIVERSIFIED CROP        2012
# 7965            FARMWORKER; DIVERSIFIED CROP        2012
# 7966            FARMWORKER; DIVERSIFIED CROP        2012
# 7967            FARMWORKER; DIVERSIFIED CROP        2012
# 7968            FARMWORKER; DIVERSIFIED CROP        2012
# 7969            FARMWORKER; DIVERSIFIED CROP        2012
# 7970            FARMWORKER; DIVERSIFIED CROP        2012
# 7971            FARMWORKER; DIVERSIFIED CROP        2012
# 7972            FARMWORKER; DIVERSIFIED CROP        2012
# 7973            FARMWORKER; DIVERSIFIED CROP        2012
# 7974            FARMWORKER; DIVERSIFIED CROP        2012
# 7975            FARMWORKER; DIVERSIFIED CROP        2012
# 7976            FARMWORKER; DIVERSIFIED CROP        2012
# 7977            FARMWORKER; DIVERSIFIED CROP        2012
# 7978            FARMWORKER; DIVERSIFIED CROP        2012
# 7979            FARMWORKER; DIVERSIFIED CROP        2012
# 7980            FARMWORKER; DIVERSIFIED CROP        2012
# 7981            FARMWORKER; DIVERSIFIED CROP        2012
# 7982            FARMWORKER; DIVERSIFIED CROP        2012
# 7983            FARMWORKER; DIVERSIFIED CROP        2012
# 7984            FARMWORKER; DIVERSIFIED CROP        2012
# 7985            FARMWORKER; DIVERSIFIED CROP        2012
#
#       certification_start_year  row_number latimes_id
# 2                       2011.0           2     2012-2
# 3                       2011.0           3     2012-3
# 4                       2011.0           4     2012-4
# 5                       2011.0           5     2012-5
# 6                       2011.0           6     2012-6
# 7                       2011.0           7     2012-7
# 8                       2011.0           8     2012-8
# 9                       2011.0           9     2012-9
# 10                      2011.0          10    2012-10
# 11                      2011.0          11    2012-11
# 12                      2011.0          12    2012-12
# 13                      2011.0          13    2012-13
# 14                      2011.0          14    2012-14
# 15                      2011.0          15    2012-15
# 16                      2011.0          16    2012-16
# 17                      2011.0          17    2012-17
# 18                      2011.0          18    2012-18
# 19                      2011.0          19    2012-19
# 20                      2011.0          20    2012-20
# 21                      2011.0          21    2012-21
# 22                      2011.0          22    2012-22
# 23                      2011.0          23    2012-23
# 24                      2011.0          24    2012-24
# 25                      2011.0          25    2012-25
# 26                      2011.0          26    2012-26
# 27                      2011.0          27    2012-27
# 28                      2011.0          28    2012-28
# 36                      2011.0          35    2012-35
# 37                      2011.0          36    2012-36
# 38                      2011.0          37    2012-37
# ...                        ...         ...        ...
# 7902                    2012.0        7718  2012-7718
# 7914                    2012.0        7727  2012-7727
# 7958                    2012.0        7766  2012-7766
# 7959                    2012.0        7767  2012-7767
# 7960                    2012.0        7768  2012-7768
# 7961                    2012.0        7769  2012-7769
# 7962                    2012.0        7770  2012-7770
# 7963                    2012.0        7771  2012-7771
# 7964                    2012.0        7772  2012-7772
# 7965                    2012.0        7773  2012-7773
# 7966                    2012.0        7774  2012-7774
# 7967                    2012.0        7775  2012-7775
# 7968                    2012.0        7776  2012-7776
# 7969                    2012.0        7777  2012-7777
# 7970                    2012.0        7778  2012-7778
# 7971                    2012.0        7779  2012-7779
# 7972                    2012.0        7780  2012-7780
# 7973                    2012.0        7781  2012-7781
# 7974                    2012.0        7782  2012-7782
# 7975                    2012.0        7783  2012-7783
# 7976                    2012.0        7784  2012-7784
# 7977                    2012.0        7785  2012-7785
# 7978                    2012.0        7786  2012-7786
# 7979                    2012.0        7787  2012-7787
# 7980                    2012.0        7788  2012-7788
# 7981                    2012.0        7789  2012-7789
# 7982                    2012.0        7790  2012-7790
# 7983                    2012.0        7791  2012-7791
# 7984                    2012.0        7792  2012-7792
# 7985                    2012.0        7793  2012-7793
#
# [2567 rows x 13 columns]

# %% [markdown]
# Process all the annual files

# %%
master_list, sub_list = zip(*[transform_xls(y) for y in sorted(schema.keys())])
# Out:
# Transforming 2008 data
# Transforming 2009 data
# Transforming 2010 data
# Transforming 2011 data
# Transforming 2012 data
# Transforming 2013 data
# Transforming 2014 data
# Transforming 2015 data
# Transforming 2016 data
# Transforming 2017 data

# %% [markdown]
# Merge all the dataframes into big ones

# %%
master_df = pd.concat(master_list)

# %%
sub_df = pd.concat(sub_list)

# %% [markdown]
# Filter out any case number that appear in multiple years

# %%
master_df.sort_values(
    ["case_number", "fiscal_year"],
    ascending=[True, False]
).drop_duplicates("case_number", keep="first", inplace=True)

# %% [markdown]
# Standardize common variations on crop names

# %%
clean_dict = {
    'Ag Eq Operator': 'Agricultural Equipment Operators',
    'Ag Eqp Operator;': 'Agricultural Equipment Operators',
    'Ag Equip Oper': 'Agricultural Equipment Operators',
    'Ag Equipment Operator': 'Agricultural Equipment Operators',
    'Ag equip operator': 'Agricultural Equipment Operators',
    'Agricultural Equipment Operator': 'Agricultural Equipment Operators',
    'Air Cured': 'Tobacco',
    'Apple Drops': 'Apples',
    'Asian Pears': 'Pears',
    'Bartlett Pears': 'Pears',
    'Bell Peppers': 'Peppers',
    'Dwarf Apples': 'Apples',
    'Romaine': 'Lettuce',
    'Spinich': 'Lettuce',
    'Spinach': 'Lettuce',
    'Onion': 'Onions',
    "Romaine Lettuce": "Lettuce",
    "Iceburg Lettuce": "Lettuce",
    "sheep": "Sheep",
    'Vineyards': 'Grapes',
    'Iceburg Lettuce': 'Lettuce',
    'Harvest Strawberries': "Strawberries",
    "Vidalia Onions": "Onion",
    'Nursery': 'Nursery or greenhouse',
    'Nursery Work': 'Nursery or greenhouse',
    "Greenhouses": 'Nursery or greenhouse',
    "Nurseries & Greenhouses": 'Nursery or greenhouse',
    'Nursery and Greenhouse Worker': 'Nursery or greenhouse',
    'Nursery and Greenhouse Workers': 'Nursery or greenhouse',
    'Purple Hull Peas': 'Other crops',
    'Sugercane': 'Sugarcane',
    'Sugar Cane': 'Sugarcane',
    'Sugarcane': 'Sugarcane',
    'Sugar Beets': 'Beets',
    'Sweet Onions': 'Onions',
    'Sweet Peppers': 'Peppers',
    'Valencia Oranges': 'Oranges',
    'Watermelon': 'Watermelons',
    'Yellow Cherries': 'Cherries',
    'Jalapeno Peppers': 'Peppers',
    'Chile Peppers': 'Peppers',
    'Kale': "Lettuce",
    "Construction of Livestock buildings": 'Construction of Livestock Buildings',
    "Construction of Livestock Buildings": "Construction of Livestock Buildings",
    "Construction, Livestock Building": "Construction of Livestock Buildings",
    'Construction of Livestock  Buildings': 'Construction of Livestock Buildings',
    'Construction of livestock buildings.': 'Construction of Livestock Buildings',
    'Construction of livestocks buildings': 'Construction of Livestock Buildings',
    'Constructionof Livestock Buildings': 'Construction of Livestock Buildings',
    'Consturcition of Livestock Buildings': 'Construction of Livestock Buildings',
    'Construction Livestock Buildings': 'Construction of Livestock Buildings',
    'Custom Combine ': 'Custom Combine',
    "Chili Peppers": "Peppers",
    "Flue Cured": "Tobacco",
    "HARVEST, GATHER, COUNT AND PACKAGE;WATERMELON": "Watermelosn",
    "Hand harvest peaches": "Peaches",
    "Harvest Corn": "Corn",
    "Harvesting Citrus and other fruits": "Citrus",
    "Harvesting Watermelons": "Watermelons",
    "Hay And Straw": "Hay",
    "Hay/Straw": "Hay",
    "Open range cattle": "Cattle",
    "ALL PRODUCITON OF HANDLING SMALL BLAES OF HAY": "Hay",
    "Grapes Harvest": "Grapes",
    "Vineyards": "Grapes",
    "Grass Hay": "Hay",
    "Hay & Straw": "Hay",
    'Straw': "Hay",
    'Straw/Hay': "Hay",
    "Straw": "Hay",
    'Straw': "Hay",
    "Custom Harvester Wheat, corn, small grain": "Wheat",
    "OPEN RANGE CATTLE": "Cattle",
    "Wathermelon Unloaders and Watermelon Packing": "Watermelons",
    'Apple': "Apples",
    'Apple Harvest': "Apples",
    'Detassel Corn': "Corn",
    'Detasseling Corn': "Corn",
    'Calves': "Cattle",
    'Calving': "Cattle",
    'Cattle Herder': "Cattle",
    'Cattle Worker': "Cattle",
    'TOBACCO': "Tobacco",
    'Tobacco - Topping & Oiling': "Tobacco",
    'Tobacco -Setting': "Tobacco",
    'Tobbaco': "Tobacco",
    'Sweet Corn': "Corn",
    'Sweet corn, harvest': "Corn",
    'Watermelosn': "Watermelons",
    'Stripping Tobacco': "Tobacco",
    "Farm worker": "Other",
    "General Farmworker": "Other",
    "Grain": "Grains",
    "Nursery Stock": "Nursery or greenhouse",
    "Sheepherder": "Sheep",
    "Farm Worker": "Other",
    "Sheep Shearer": "Sheep",
}

# %%
master_df['latimes_crop'] = master_df.apply(lambda x: clean_dict.get(x.crop, x.crop), axis=1)

# %%
sub_df['latimes_crop'] = sub_df.apply(lambda x: clean_dict.get(x.crop, x.crop), axis=1)

# %% [markdown]
# Create a combined file that merges master and sub cases.

# %% [markdown]
# First, sum up the total number of workers certified for subcases of each case number

# %%
subcase_workers = sub_df.groupby("case_number").agg(dict(workers_certified="sum")).reset_index()

# %%
subcase_workers.columns = ['case_number', 'workers_subcases']

# %%
# Added by Steve, What does subcase_workers look like?
subcase_workers.head()
# Out:
#      case_number  workers_subcases
# 0  A-07297-04840                43
# 1  A-07299-04849                 8
# 2  A-07325-04931                 4
# 3  A-07327-04937                17
# 4  A-07337-04977                22

# %% [markdown]
# Merge that number to the master list for comparison

# %%
# Added by Steve, the set of subcase_workers.case_numbers is a subset of master_df.case_numbers
# No harm, no foul.
print(set(subcase_workers.case_number.unique()).difference(set(master_df.case_number.unique())))
print(set(master_df.case_number.unique()).difference(set(subcase_workers.case_number.unique())))
# Out:
# set([])
# set([u'H-300-15147-616842', u'H-300-12347-366077', u'C-09051-18118', u'H-300-16195-816695', u'H-300-16250-762829', u'H-300-16019-547984', u'H-300-14358-619565', u'H-300-14028-845983', u'H-300-15055-077364', u'H-300-16046-400511', u'H-300-16200-841542', u'C-11010-26429', u'C-11010-26428', u'H-300-15005-471529', u'C-11010-26421', u'C-11010-26420', u'C-11010-26423', u'C-11010-26422', u'C-11010-26425', u'C-11010-26424', u'C-11010-26427', u'C-11010-26426', u'H-300-16210-196149', u'H-300-12361-617846', u'H-300-16117-218788', u'H-300-15035-010396', u'H-300-13164-103549', u'H-300-16355-986491', u'H-300-15355-077404', u'H-300-15017-714125', u'H-300-13352-061383', u'C-12122-34329', u'H-300-15133-697611', u'A-08050-05985', u'C-09083-18958', u'A-08050-05987', u'A-08050-05986', u'A-08050-05981', u'A-08050-05980', u'A-08050-05983', u'A-08050-05982', u'H-300-14150-330799', u'A-08050-05989', u'A-08050-05988', u'C-09083-18957', u'C-09083-18956', u'H-300-13297-670596', u'C-11362-31117', u'C-11362-31116', u'C-08276-14921', u'H-300-16027-573098', u'C-08276-14922', u'H-300-16320-193704', u'C-11362-31119', u'C-11362-31118', u'H-300-14027-248796', u'H-300-14129-666327', u'H-300-15008-798369', u'H-300-17037-052134', u'H-300-16364-714695', u'H-300-13007-257356', u'H-300-17066-894316', u'H-300-13142-094321', u'H-300-16104-709845', u'H-300-13133-528271', u'H-300-13140-632678', u'H-300-13043-270012', u'H-300-16077-928327', u'C-09299-20810', u'H-300-16363-045836', u'H-300-15024-342233', u'H-300-14154-575530', u'H-300-15039-804385', u'C-09153-19819', u'H-300-14043-785441', u'C-09153-19815', u'C-09153-19814', u'C-09153-19817', u'C-09153-19816', u'C-08008-07601', u'C-08008-07603', u'C-08008-07602', u'C-08008-07605', u'C-08008-07604', u'C-08008-07607', u'C-08008-07606', u'H-300-16029-442444', u'H-300-15154-968003', u'C-10090-24000', u'C-10090-24001', u'H-300-13024-372402', u'H-300-16022-376810', u'A-07339-05018', u'C-09009-16759', u'H-300-15051-058934', u'H-300-13028-114554', u'H-300-16089-304534', u'A-07330-04938', u'H-300-15040-229550', u'H-300-15125-912916', u'C-11167-29568', u'H-300-16070-674325', u'H-300-16235-673636', u'H-300-13067-489130', u'C-10323-25537', u'H-300-17012-761636', u'H-300-16048-278590', u'H-300-13059-661646', u'H-300-16308-815268', u'C-10323-25531', u'H-300-14079-941952', u'H-300-17013-265425', u'C-07302-06558', u'H-300-17012-808403', u'H-300-16342-883905', u'H-300-16046-432860', u'H-300-15188-864194', u'H-300-14115-693642', u'H-300-13158-630111', u'C-11038-27398', u'C-11038-27399', u'C-11038-27396', u'C-11038-27397', u'C-11038-27394', u'C-11038-27395', u'C-11038-27392', u'C-11038-27393', u'C-11038-27391', u'H-300-13163-037870', u'H-300-13296-925468', u'H-300-17013-937509', u'C-12145-34666', u'H-300-14056-554367', u'H-300-16089-452893', u'H-300-17017-053965', u'H-300-15342-921151', u'H-300-13040-480126', u'H-300-15346-691538', u'H-300-16130-779362', u'H-300-13193-891682', u'H-300-15254-789314', u'H-300-13063-849512', u'H-300-16294-245352', u'H-300-12346-305382', u'H-300-14190-742544', u'H-300-14092-368828', u'H-300-17054-819661', u'H-300-16043-709940', u'H-300-14059-339625', u'C-11257-30056', u'C-11257-30054', u'C-11257-30055', u'C-11257-30052', u'C-11257-30053', u'C-11257-30050', u'C-11257-30051', u'H-300-14328-452805', u'H-300-17028-978597', u'H-300-17013-499367', u'H-300-17022-576026', u'H-300-16021-312438', u'H-300-15363-620209', u'C-11045-27693', u'C-11045-27691', u'C-11045-27690', u'C-11045-27697', u'C-11045-27696', u'C-11045-27695', u'C-11045-27694', u'H-300-13122-424894', u'C-11045-27699', u'C-11045-27698', u'C-08239-14623', u'H-300-16230-369214', u'C-09026-17445', u'C-09026-17444', u'C-09026-17447', u'C-09026-17446', u'C-09026-17440', u'C-09026-17443', u'C-09026-17442', u'C-09026-17449', u'C-09026-17448', u'H-300-15183-388929', u'H-300-14343-939247', u'H-300-17053-348861', u'H-300-16027-416378', u'H-300-13067-885262', u'C-11124-29208', u'C-11124-29209', u'H-300-17020-044268', u'H-300-13158-587498', u'H-300-15026-333663', u'C-11 ...

# %%
combined_df = pd.merge(
    master_df,
    subcase_workers,
    how="left",
    on="case_number"
)

# %%
# Added by Steve, what exactly was merged?

print('master_df schema\n' + str(master_df.dtypes) + '\n\nsubcase_workers schema\n' + str(subcase_workers.dtypes))
# Out:
# master_df schema
# case_number                         object
# case_status                         object
# certification_start_date    datetime64[ns]
# certification_start_year           float64
# city                                object
# crop                                object
# employer                            object
# fiscal_year                          int64
# job_title                           object
# latimes_id                          object
# master_case                           bool
# row_number                           int64
# state                               object
# workers_certified                    int64
# latimes_crop                        object
# dtype: object
#
# subcase_workers schema
# case_number         object
# workers_subcases     int64
# dtype: object

# %% [markdown]
# Append all subcases with case numbers that appear in the master list to the combined list

# %%
linked_subcases = sub_df[sub_df.case_number.isin(combined_df.case_number)]

# %%
# Added by Steve, how many linked subcases
sum(sub_df.case_number.isin(combined_df.case_number))
# Out:
# 25984

# %%
linked_subcases['sub_case'] = True

# %%
combined_df = combined_df.append(linked_subcases)

# %% [markdown]
# Zero out the subcases worker count where it is empty

# %%
combined_df.workers_subcases.fillna(0, inplace=True)

# %% [markdown]
# Calculate a net worker count by subtracting the subcase count from the total. This prevents double counting subcase positions included in master cases.

# %%
combined_df['net_workers'] = combined_df.apply(
    lambda x: x.workers_certified - x.workers_subcases,
    axis=1
)

# %% [markdown]
# Drop master cases with zero workers after subtracting their subcases

# %%
net_df = combined_df[combined_df.net_workers > 0]

# %% [markdown]
# Write out the transformed files for analysis

# %%
master_df.to_csv(
    os.path.join(output_dir, "transformed_master_cases.csv"),
    index=False,
    encoding="utf-8"
)

# %%
sub_df.to_csv(
    os.path.join(output_dir, "transformed_sub_cases.csv"),
    index=False,
    encoding="utf-8"
)

# %%
net_df.to_csv(
    os.path.join(output_dir, "transformed_all_cases.csv"),
    index=False,
    encoding="utf-8"
)
